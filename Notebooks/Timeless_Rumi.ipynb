# %% [markdown]
# Timeless Rumi
#
# रसततम ऎज़ीन नफ़स वहवा ज़यदह बला मरदह बला
# ज़नदह व मरदह वत़नम नीसत बजज़ फ़ॹल ख़दा!
# रसतम ऎज़ीन बीत? व ग़ज़ल; ए शह व सलत़ान ऎज़ल!
# मफ़तएलन मफ़तएलन मफ़तएलन कशत मरा

# %%
# %%bash
# git clone https://github.com/hindawiai/chintamani
# cd chintamani/Romenagri
# wget https://archive.org/stream/GuzeedaEGhazaliyatEShams-MaulanaJalaluddinMuhammadBalkhiFarsi/guzeeda%20e%20ghazaliyat%20e%20shams_djvu.txt -O farsi.txt
# cat farsi.txt | ./fltr_ur_hi > dev.txt
# Out:
# fatal: destination path 'chintamani' already exists and is not an empty directory.
# --2025-09-27 00:09:01--  https://archive.org/stream/GuzeedaEGhazaliyatEShams-MaulanaJalaluddinMuhammadBalkhiFarsi/guzeeda%20e%20ghazaliyat%20e%20shams_djvu.txt
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘farsi.txt’
#
#      0K .......... .......... .......... .......... ..........  720K
#     50K .......... .......... .......... .......... ..........  727K
#    100K .......... .......... .......... .......... .......... 60.2M
#    150K .......... .......... .......... .......... ..........  156M
#    200K .......... .......... .......... .......... ..........  746K
#    250K .......... .......... .......... .......... .......... 32.0M
#    300K .......... .......... .......... .......... ..........  206M
# ...

# %% [markdown]
# Rumi's collection accessed from https://archive.org/details/GuzeedaEGhazaliyatEShams-MaulanaJalaluddinMuhammadBalkhiFarsi
